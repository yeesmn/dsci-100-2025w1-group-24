# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %%
players <- read_csv("data/players.csv")
players

sessions <- read_csv("data/sessions.csv")
sessions

# %%
sessions <- sessions |>
    mutate(start_time = dmy_hm(start_time),
           end_time = dmy_hm(end_time),
          play_time = as.numeric(difftime(end_time, start_time)))

sessions
